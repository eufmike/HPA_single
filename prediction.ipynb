# %%
# %load_ext autoreload
# %autoreload 2
import os, sys
import logging
from pathlib import Path
from tqdm import tqdm
import yaml
from func.trainer import Trainer, Trainer_ln, Train_Project

# %%
config_path = "/dlab/ldrive/CBT/USLJ-DSDE-I10007/DSDE/shihch3/code/p/python/HPA_single/config/config_ln_dev_10.yaml"
config = yaml.safe_load(open(config_path, "r"))
gpu_device = [0]
tbdir = Path("/dlab/ldrive/CBT/USLJ-DSDE_DATA-I10008/shihch3/projects/HPA_single_data/training_tblog_ln/")
ckp_path = tbdir.joinpath('lightning_logs_2024_03_13', 'version_7', 'checkpoints', 'ckpt_034-vloss_0.3169_vf1_0.1414.ckpt')
train_prj = Train_Project(config)
train_prj.load_train_objs()
train_prj.prepare_pred_dataloader()
trainer = Trainer_ln(train_prj, gpu_device)
# Out:
# INFO:root:2024-03-13 15:47:04,293:{'dir': {'data': '/dlab/ldrive/CBT/USLJ-DSDE_DATA-I10008/BenchmarkDatasets/hpa-single-cell-image-classification',
#          'img': '/dlab/ldrive/CBT/USLJ-DSDE_DATA-I10008/shihch3/projects/HPA_single_data/code_test/img',
#          'project': '/dlab/ldrive/CBT/USLJ-DSDE_DATA-I10008/shihch3/projects/HPA_single_data'},
#  'train': {'dataload': {'GPU_num': 2,
#                         'batch_size': 12,
#                         'dataset_csv': 'train.csv',
#                         'dataset_folder': 'train',
#                         'deterministic': False,
#                         'input_ch_ct': 4,
#                         'mean': [24.96067158,
#                                  16.44201136,
#                                  15.88478792,
#                                  25.09126955],
#                         'model_input_size': [1024, 1024],
#                         'n_class': 19,
#                         'num_workers': 8,
# ...

# %%
trainer.prediction(ckp_path)
# Out:
# INFO:root:2024-03-13 15:47:07,236:custom_resnet(
#   (conv1): Conv2d(4, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(3, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (resnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
